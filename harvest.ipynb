# %% [markdown]
# ## Collect Metadata from Michigan PLSS Plats Survey Maps
#
# This Jupyter Notebook is intended to collect useful metadata from separated `OPEX` files of Michigan PLSS Plats. The contents for these `OPEX` files are formatted as `XML`. Thus, in this documentation, we mainly use the **BeautifulSoup** python library to help pull data out of it.
#
# ### file structure
# - **harvest.ipynb**
# - **RG_87-155_GLO_Survey_Maps_1816-1860** contains different subdirectories for all Michigan townships. There might be one or more than one `.pax.zip.opex` file indicating the plat of each township.
# - **bbox of MI townships.csv** offers the bounding box for each Michigan township.
# - **metadata.csv** is the output CSV file with all plats' metadata
#
# > Original created on May 27 2021
# > @author: Gene/Ziying Cheng @Ziiiiing

# %%
import os
from bs4 import BeautifulSoup
import time
import csv
import geocoder

# %%
subdirs =  os.listdir('RG_87-155_GLO_Survey_Maps_1816-1860') 

fieldnames = ['Title', 'Alternative Title', 'Description', 'Language', 'Creator', 'Publisher',
              'Resource Type', 'Date Issued', 'Temporal Coverage', 'Date Range',
              'Spatial Coverage', 'Bounding Box', 'Information', 'Download', 'Image', 
              'Identifier', 'ID', 'Access Rights', 'Provider', 'Code', 'Member Of', 'Status', 
              'Accrual Method', 'Date Accessioned', 'Rights', 'Resource Class', 'Format',
              'Suppressed', 'Child Record']

# %%
bboxDict = {}
with open('bbox of MI townships.csv') as fr:
    reader = csv.reader(fr)
    fields = next(reader)
    for row in reader:
        bboxDict[row[11]] = row[12]

# %%
def collectMetadata(data):
    metadata = []
    soup = BeautifulSoup(data,'xml')
    
    alternativeTitle = soup.find('title').get_text()
    description = soup.find('abstract').get_text()
    language = soup.find('languageTerm').get_text()
    if language == 'English':
        language = 'eng'

    creator = ''
    creatorElem = soup.find_all(displayLabel="Surveyor")
    for elem in creatorElem:
        if creator:
            creator += '|' + elem.get_text()
        else:
            creator = elem.get_text()

    publisher = soup.find(displayLabel="Agency").get_text()
        
    try:
        dateIssued = soup.find('dateCreated').get_text()
    except:
        dateIssued = ''        
        
    township = soup.find('township').get_text()
    county = soup.find('county').get_text()
    spatialCoverage = '{0}, {1}, Michigan|{1}, Michigan|Michigan'.format(township, county)
        
    TWNSHPLAB =  subdir.split('_')[0].strip('0') + ' ' + subdir.split('_')[1].strip('0')
    try:
        bbox = bboxDict[TWNSHPLAB]
    except:
        bbox = ''
    
    identifier = soup.find('Identifier').get_text()
    ID = soup.find('SourceID').get_text()
    information = 'https://michiganology.org/uncategorized/IO_' + ID
    download = 'https://michiganology.org/download/file/IO_' + ID
    image = 'https://michiganology.org/download/thumbnail/IO_' + ID
    
    rights = soup.find(type="restriction on access").get_text() + ' ' + soup.find(type="use").get_text()
    
    title = ''
    temporalCoverage = ''
    dateRange = ''
    resourceType = 'Cadastral maps'
    accessRights = 'Public'
    provider = 'Michigan State University'
    code = '06a-03'
    memberOf = '06a-03'
    status = 'Active'
    accrualMethod = 'OPEX'
    dateAccessioned = time.strftime('%Y-%m-%d')
    resourceClass = 'Maps'
    format = 'JPEG2000'
    suppressed = 'FALSE'
    childRecord = 'FALSE'
    
    
    metadata = [title, alternativeTitle, description, language, creator, publisher, resourceType,
                dateIssued, temporalCoverage, dateRange,spatialCoverage, bbox, information,
                download, image, identifier, ID, accessRights, provider, code, memberOf, status,
                accrualMethod, dateAccessioned, rights, resourceClass, format, suppressed, childRecord]

    All_Metadata.append(metadata)

# %%
All_Metadata = []

for subdir in subdirs:
    # skip hidden files
    if '.' in subdir:
        continue
    
    print('SEARCHING {}'.format(subdir))
    dirpath = 'RG_87-155_GLO_Survey_Maps_1816-1860/{}'.format(subdir)
    filepaths = ['{}/{}'.format(dirpath, f) for f in os.listdir(dirpath) if f.endswith('.pax.zip.opex')]
    for filepath in filepaths:
        print('>>> reading {}'.format(filepath.split('/')[-1]))
        with open(filepath) as fr:
            contents = fr.read()
            collectMetadata(contents)
# Out:
# SEARCHING 45N_26W_-_Survey_Map_of_Forsyth_Township_Marquette_County
# >>> reading 2208.pax.zip.opex
# SEARCHING 34N_27W_-_Survey_Map_of_Mellen_Township_Menominee_County
# >>> reading 2746.pax.zip.opex
# SEARCHING 08N_08E_-_Survey_Map_or_Richfield_Township_Genesee_County
# >>> reading 1836.pax.zip.opex
# SEARCHING 47N_42W_-_Survey_Map_of_Mareninsco_Township_Gogebic_County
# >>> reading 2456.pax.zip.opex
# SEARCHING 43N_32W_-_Survey_Map_of_Crystal_Falls_Township_Iron_County
# >>> reading 2948.pax.zip.opex
# >>> reading 2949.pax.zip.opex
# SEARCHING 48N_38W_-_Survey_Map_of_Stannard_Township_and_Interior_Township_
# >>> reading 2562.pax.zip.opex
# SEARCHING 12N_03W_-_Survey_Map_of_Pine_River_Township_Gratiot_County
# >>> reading 719.pax.zip.opex
# SEARCHING 34N_02E_-_Survey_Map_of_Allis_Township_Presque_Isle_County
# >>> reading 1131.pax.zip.opex
# SEARCHING 32N_03W_-_Survey_Map_of_Corwith_Township_Otsego_County
# >>> reading 1072.pax.zip.opex
# SEARCHING 02N_07W_-_Survey_Map_of_Maple_Grove_Township_Barry_County
# >>> reading 344.pax.zip.opex
# SEARCHING 47N_09W_-_Survey_Map_of_McMillan_Township_Luce_County
# >>> reading 2127.pax.zip.opex
# SEARCHING 41N_11W_-_Survey_Map_of_Newton_Township_Mackinac_County
# >>> reading 2154.pax.zip.opex
# SEARCHING 45N_01W_-_Survey_Map_of_Kinross_Township_Bruce_Township_and_Daft
# >>> reading 2048.pax.zip.opex
# SEARCHING 05S_14W_-_Survey_Map_of_Volina_Township_Cass_County
# >>> reading 2780.pax.zip.opex
# SEARCHING 09N_14W_-_Survey_Map_of_Ravenna_Township_Muskegon_County
# >>> reading 449.pax.zip.opex
# SEARCHING 30N_01W_-_Survey_Map_of_Charlton_Township_Otsego_County
# >>> reading 742.pax.zip.opex
# SEARCHING 39N_04W_-_Survey_Map_of_Wawatam_Township_Emmet_County
# >>> reading 1093.pax.zip.opex
# SEARCHING 15N_01E_-_Survey_Map_of_Lincoln_Township_Midland_County
# >>> reading 1350.pax.zip.opex
# SEARCHING 59N_27W_-_Survey_Map_of_Grant_Township_Keweenaw_County
# >>> reading 2377.pax.zip.opex
# SEARCHING 14N_05E_-_Survey_Map_of_Bangor_Township_and_Hampton_Township_Bay
# >>> reading 2923.pax.zip.opex
# >>> reading 2922.pax.zip.opex
# >>> reading 2919.pax.zip.opex
# >>> reading 2918.pax.zip.opex
# >>> reading 2920.pax.zip.opex
# >>> reading 2921.pax.zip.opex
# SEARCHING 14N_05W_-_Survey_Map_of_Deerfield_Township_Isabella_County
# >>> reading 658.pax.zip.opex
# SEARCHING 05N_10W_-_Survey_Map_of_Caledonia_Township_Kent_County
# >>> reading 411.pax.zip.opex
# >>> reading 410.pax.zip.opex
# SEARCHING 65N_36W_-_Survey_Map_of_Eagle_Harbor_Township_Isle_Royale_County
# >>> reading 2343.pax.zip.opex
# >>> reading 2344.pax.zip.opex
# SEARCHING 37N_11W_-_Survey_Map_of_Big_Beaver_Island_Peaine_Township_Charle
# >>> reading 2788.pax.zip.opex
# SEARCHING 07N_08W_-_Survey_Map_of_Keene_Township_Ionia_County
# >>> reading 324.pax.zip.opex
# >>> reading 325.pax.zip.opex
# SEARCHING 47N_32W_-_Survey_Map_of_Spurr_Township_Baraga_County
# >>> reading 2904.pax.zip.opex
# SEARCHING 25N_06E_-_Survey_Map_of_Curtis_Township_Alcona_County
# >>> reading 1323.pax.zip.opex
# SEARCHING 45N_43W_-_Survey_Map_of_Mareninsco_Township_Gogebic_County
# >>> reading 2466.pax.zip.opex
# SEARCHING 45N_19W_-_Survey_Map_of_Au_Train_Township_and_Munising_Townships
# >>> reading 2094.pax.zip.opex
# >>> reading 2093.pax.zip.opex
# SEARCHING 48N_46W_-_Survey_Map_of_Ironwood_Township_Gogebic_County
# >>> reading 2517.pax.zip.opex
# SEARCHING 49N_33W_-_Survey_Map_of_LAnse_Township_Baraga_County
# >>> reading 2896.pax.zip.opex
# SEARCHING 15N_05E_-_Survey_map_of_Bangor_Township_Bay_County
# >>> reading 1364.pax.zip.opex
# SEARCHING 12N_06E_-_Survey_Map_of_Blumfield_Township_Saginaw_County
# >>> reading 1482.pax.zip.opex
# SEARCHING 06N_04E_-_Survey_Map_of_Vernon_Township_Shiawassee_County
# >>> reading 1569.pax.zip.opex
# >>> reading 1570.pax.zip.opex
# SEARCHING 45N_40W_-_Survey_Map_of_Watersmeet_Township_Gogebic_County
# >>> reading 2637.pax.zip.opex
# >>> reading 2638.pax.zip.opex
# SEARCHING 27N_16W_-_Survey_Map_of_Lake_Township_Benzie_County
# >>> reading 962.pax.zip.opex
# SEARCHING 14N_01W_-_Survey_Map_of_Lee_Township_Midland_County
# >>> reading 714.pax.zip.opex
# SEARCHING 23N_01E_-_Survey_Map_of_Foster_Township_Ogemaw_County
# >>> reading 1208.pax.zip.opex
# SEARCHING 48N_26W_-_Survey_Map_of_Neguanee_Township_Marquette_County
# >>> reading 2284.pax.zip.opex
# SEARCHING 27N_02W_-_Survey_Map_of_Grayling_Township_Crawford_County
# >>> reading 754.pax.zip.opex
# SEARCHING 43N_26W_-_Survey_Map_of_Wells_Township_Marquette_County
# >>> reading 2223.pax.zip.opex
# SEARCHING 42N_15W_-_Survey_Map_of_Manistique_Township_Schoolcraft_County
# >>> reading 2184.pax.zip.opex
# SEARCHING 41N_19W_-_Survey_Map_of_Nahma_Township_Delta_County
# >>> reading 2236.pax.zip.opex
# SEARCHING 31N_05E_-_Survey_Map_of_Green_Township_and_Wellington_Township_A
# >>> reading 1140.pax.zip.opex
# SEARCHING 07S_16W_-_Survey_Map_of_Howard_Township_Cass_County
# >>> reading 30.pax.zip.opex
# SEARCHING 32N_07W_-_Survey_Map_of_South_Arm_Township_Charlevoix_County
# >>> reading 2861.pax.zip.opex
# SEARCHING 03S_05E_-_Survey_Map_of_Lodi_Township_Washtenaw_County
# >>> reading 1618.pax.zip.opex
# SEARCHING 07N_09E_-_Survey_Map_of_Elba_Township_Lapeer_County
# >>> reading 1616.pax.zip.opex
# SEARCHING 47N_36W_-_Survey_Map_of_Duncan_Township_Houghton_County
# >>> reading 2887.pax.zip.opex
# SEARCHING 13N_06W_-_Survey_Map_of_Rolland_Township_Isabella_County
# >>> reading 661.pax.zip.opex
# SEARCHING 51N_40W_-_Survey_Map_of_Ontonagon_Township_Ontonagon_County
# >>> reading 2502.pax.zip.opex
# SEARCHING 14N_09E_-_Survey_Map_of_Columbia_Township_Tuscola_County
# >>> reading 1468.pax.zip.opex
# SEARCHING 04S_09W_-_Survey_Map_of_Wakeshma_Township_Kalamazoo_County
# >>> reading 182.pax.zip.opex
# SEARCHING 08N_11W_-_Survey_Map_of_Plainfield_Township_Kent_County
# >>> reading 373.pax.zip.opex
# >>> reading 374.pax.zip.opex
# SEARCHING 36N_28W_-_Survey_Map_of_Holmes_Township_and_Lake_Township_Menomi
# >>> reading 2769.pax.zip.opex
# >>> reading 2768.pax.zip.opex
# SEARCHING 39N_28W_-_Survey_Map_of_Waucedah_Township_Dickinson_County
# >>> reading 2695.pax.zip.opex
# SEARCHING 42N_10W_-_Survey_Map_of_Garfield_Township_Mackinac_County
# >>> reading 2153.pax.zip.opex
# SEARCHING 67N_32W_-_Survey_Map_of_Passage_Island_Houghton_Township_Isle_Ro
# >>> reading 2364.pax.zip.opex
# SEARCHING 52N_36W_-_Survey_Map_of_Elm_River_Township_and_Portage_Township_
# >>> reading 2491.pax.zip.opex
# SEARCHING 04S_07W_-_Survey_Map_of_Burlington_Township_Calhoun_County
# >>> reading 180.pax.zip.opex
# SEARCHING 06N_10E_-_Survey_Map_of_Metamora_Township_Lapeer_County
# >>> reading 1825.pax.zip.opex
# SEARCHING 17N_10E_-_Survey_Map_of_McKinley_and_Caseville_Townships_Huron_C
# >>> reading 1367.pax.zip.opex
# SEARCHING 07N_02E_-_Survey_Map_of_Owosso_Township_Shiawassee_County
# >>> reading 1562.pax.zip.opex
# SEARCHING 23N_15W_-_Survey_Map_of_Bear_Lake_Township_Manistee_County
# >>> reading 987.pax.zip.opex
# SEARCHING 25N_04W_-_Survey_Map_of_Beaver_Creek_Township_Crawford_County
# >>> reading 759.pax.zip.opex
# SEARCHING 41N_25W_-_Survey_Map_of_Harris_Township_Menominee_County
# >>> reading 2253.pax.zip.opex
# SEARCHING 03S_09E_-_Survey_Map_of_Romulus_Township_Wayne_County
# >>> reading 1631.pax.zip.opex
# SEARCHING 10N_14E_-_Survey_Map_of_Elk_Township_Sanilac_County
# >>> reading 1541.pax.zip.opex
# SEARCHING 08S_05W_-_Survey_Map_of_California_Township_Branch_County
# >>> reading 231.pax.zip.opex
# SEARCHING 44N_33W_-_Survey_Map_of_Crystal_Falls_Township_and_Hematite_Town
# >>> reading 2623.pax.zip.opex
# SEARCHING 38N_18W_-_Survey_Map_of_Garden_Township_Delta_County
# >>> reading 2705.pax.zip.opex
# SEARCHING 28N_06W_-_Survey_Map_of_Cold_Springs_Township_Kalkaska_County
# >>> reading 847.pax.zip.opex
# >>> reading 844.pax.zip.opex
# SEARCHING 34N_29W_-_Survey_Map_of_Lake_Township_Menominee_County
# >>> reading 2748.pax.zip.opex
# SEARCHING 05N_12W_-_Survey_Map_of_Byron_Township_Kent_County
# >>> reading 398.pax.zip.opex
# SEARCHING 05N_13E_-_Survey_Map_of_Armada_Township_Macomb_County
# >>> reading 1605.pax.zip.opex
# SEARCHING 41N_07E_-_Survey_Map_of_Drummond_Island_Chippewa_County
# >>> reading 1966.pax.zip.opex
# >>> reading 1965.pax.zip.opex
# >>> reading 1964.pax.zip.opex
# SEARCHING 25N_05W_-_Survey_Map_of_Garfield_Township_Kalkaska_County
# >>> reading 837.pax.zip.opex
# SEARCHING 48N_27W_-_Survey_Map_of_Ishpeming_Township_and_Neguanee_Township
# >>> reading 2285.pax.zip.opex
# SEARCHING 33N_04W_-_Survey_Map_of_Chandler_Township_Charlevoix_County
# >>> reading 994.pax.zip.opex
# SEARCHING 44N_36W_-_Survey_Map_of_Iron_River_Township_Iron_County
# >>> reading 2601.pax.zip.opex
# SEARCHING 23N_14W_-_Survey_Map_of_Maple_Grove_Township_Manistee_County
# >>> reading 982.pax.zip.opex
# SEARCHING 44N_35W_-_Survey_Map_of_Iron_River_Township_and_Bates_Township_I
# >>> reading 2622.pax.zip.opex
# SEARCHING 18N_02W_-_Survey_Map_of_Grout_Township_Gladwin_County
# >>> reading 691.pax.zip.opex
# SEARCHING 07N_10W_-_Survey_Map_of_Ada_Township_Kent_County
# >>> reading 385.pax.zip.opex
# >>> reading 386.pax.zip.opex
# SEARCHING 16N_01W_-_Survey_Map_of_Edenville_Township_Midland_County
# >>> reading 699.pax.zip.opex
# SEARCHING 33N_04E_-_Survey_Map_of_Bismark_Township_Presque_Isle_County
# >>> reading 1121.pax.zip.opex
# SEARCHING 04N_15W_-_Survey_Map_of_Fillmore_Township_Allegan_County
# >>> reading 466.pax.zip.opex
# SEARCHING 05N_04W_-_Survey_Map_of_Eagle_Township_Clinton_County
# >>> reading 276.pax.zip.opex
# >>> reading 275.pax.zip.opex
# SEARCHING 50N_35W_-_Survey_Map_of_Laird_Township_Houghton_County_and_Barag
# >>> reading 2615.pax.zip.opex
# SEARCHING 16N_07W_-_Survey_Map_of_Fork_Township_Mecosta_County
# >>> reading 648.pax.zip.opex
# SEARCHING 13N_10E_-_Survey_Map_of_Ellington_Township_Tuscola_County
# >>> reading 1472.pax.zip.opex
# SEARCHING 03N_07E_-_Survey_Map_of_Highland_Township_Oakland_County
# >>> reading 1871.pax.zip.opex
# SEARCHING 02S_07E_-_Survey_Map_of_Superior_Township_Washtenaw_County
# >>> reading 1776.pax.zip.opex
# SEARCHING 41N_30W_-_Survey_Map_of_Breitung_Township_Dickinson_County
# >>> reading 3011.pax.zip.opex
# SEARCHING 02N_14E_-_Survey_Map_of_Harrison_Township_Macomb_County
# >>> reading 1819.pax.zip.opex
# SEARCHING 04S_09E_-_Survey_Map_of_Huron_Township_Wayne_County
# >>> reading 1645.pax.zip.opex
# >>> reading 1644.pax.zip.opex
# SEARCHING 43N_02E_-_Survey_Map_of_Raber_Township_Chippewa_County
# >>> reading 1885.pax.zip.opex
# SEARCHING 16N_13E_-_Survey_Map_of_Verona_Township_Huron_County
# >>> reading 1492.pax.zip.opex
# SEARCHING 23N_06W_-_Survey_Map_of_West_Branch_Township_Missaukee_County
# >>> reading 878.pax.zip.opex
# SEARCHING 32N_15W_-_Survey_Map_of_North_Manitou_Island_Leland_Township_Lee
# >>> reading 2825.pax.zip.opex
# >>> reading 2824.pax.zip.opex
# SEARCHING 40N_26W_-_Survey_Map_of_Spalding_Township_Menominee_County
# >>> reading 2709.pax.zip.opex
# SEARCHING 07S_08W_-_Survey_Map_of_Bronson_Township_Branch_County
# >>> reading 204.pax.zip.opex
# SEARCHING 32N_28W_-_Survey_Map_of_Menominee_Township_Menominee_County
# >>> reading 2755.pax.zip.opex
# SEARCHING 33N_08W_-_Survey_Map_of_Marion_Township_Charlevoix_County
# >>> reading 992.pax.zip.opex
# SEARCHING 48N_13W_-_Survey_Map_of_Burt_Township_Alger_County
# >>> reading 2073.pax.zip.opex
# >>> reading 2072.pax.zip.opex
# SEARCHING 08N_09W_-_Survey_Map_of_Grattan_Township_Kent_County
# >>> reading 376.pax.zip.opex
# >>> reading 377.pax.zip.opex
# SEARCHING 48N_16W_-_Survey_Map_of_Burt_Township_Alger_County
# >>> reading 2172.pax.zip.opex
# SEARCHING 15N_09W_-_Survey_Map_of_Colfax_Township_Mecosta_County
# >>> reading 615.pax.zip.opex
# >>> reading 616.pax.zip.opex
# SEARCHING 23N_06E_-_Survey_Map_of_Plainfield_Township_Iosco_County
# >>> reading 1257.pax.zip.opex
# >>> reading 1256.pax.zip.opex
# >>> reading 1255.pax.zip.opex
# SEARCHING 30N_08W_-_Survey_Map_of_Forest_Home_Township_Antrim_County
# >>> reading 845.pax.zip.opex
# SEARCHING 04S_06W_-_Survey_Map_of_Tekonsha_Township_Calhoun_County
# >>> reading 188.pax.zip.opex
# >>> reading 187.pax.zip.opex
# SEARCHING 35N_01E_-_Survey_Map_of_Waverly_Township_Cheboygan_County
# >>> reading 1108.pax.zip.opex
# SEARCHING 47N_43W_-_Survey_Map_of_Mareninsco_Township_Gogebic_County
# >>> reading 2448.pax.zip.opex
# SEARCHING 43N_33W_-_Survey_Map_of_Crystal_Falls_Township_Iron_County
# >>> reading 2952.pax.zip.opex
# >>> reading 2951.pax.zip.opex
# SEARCHING 08S_08W_-_Survey_Map_of_Nobel_Township_Branch_County
# >>> reading 234.pax.zip.opex
# SEARCHING 31N_08W_-_Survey_Map_of_Central_Lake_Township_Antrim_County
# >>> reading 1077.pax.zip.opex
# SEARCHING 31N_08E_-_Survey_Map_of_Alpena_Township_Alpena_County
# >>> reading 1147.pax.zip.opex
# SEARCHING 34N_25W_-_Survey_Map_of_Ingallston_Township_Menominee_County
# >>> reading 2745.pax.zip.opex
# SEARCHING 02N_01E_-_Survey_Map_of_Ingham_Township_Ingham_County
# >>> reading 1593.pax.zip.opex
# SEARCHING 13N_03E_-_Survey_Map_of_Tittabawassee_Township_Saginaw_County
# >>> reading 1286.pax.zip.opex
# >>> reading 1285.pax.zip.opex
# SEARCHING 42N_22W_-_Survey_Map_of_Baldwin_Township_Delta_County
# >>> reading 2249.pax.zip.opex
# SEARCHING 21N_06E_-_Survey_Map_of_Sherman_Township_Iosco_County
# >>> reading 1330.pax.zip.opex
# SEARCHING 42N_01E_-_Survey_Map_of_Clark_Township_Mackinac_County
# >>> reading 1888.pax.zip.opex
# SEARCHING 43N_30W_-_Survey_Map_of_Sagola_Township_Dickinson_County
# >>> reading 3003.pax.zip.opex
# SEARCHING 32N_01E_-_Survey_Map_of_Montmorency_Township_Montmorency_County
# >>> reading 1139.pax.zip.opex
# SEARCHING 46N_28W_-_Survey_Map_of_Ely_Township_Marquette_County
# >>> reading 2299.pax.zip.opex
# SEARCHING 39N_18W_-_Survey_Map_of_Garden_Township_Delta_County
# >>> reading 2688.pax.zip.opex
# SEARCHING 14N_10E_-_Survey_Map_of_Elmwood_Township_Tuscola_County
# >>> reading 1469.pax.zip.opex
# SEARCHING 36N_01W_-_Survey_Map_of_Aloha_Township_Cheboygan_County
# >>> reading 1091.pax.zip.opex
# SEARCHING 22N_08W_-_Survey_Map_of_Lake_Township_Missaukee_County
# >>> reading 868.pax.zip.opex
# >>> reading 869.pax.zip.opex
# >>> reading 871.pax.zip.opex
# SEARCHING 41N_23W_-_Survey_Map_of_Baldwin_and_Cornell_Townships_Delta_Coun
# >>> reading 2251.pax.zip.opex
# SEARCHING 04N_13W_-_Survey_Map_of_Salem_Township_Allegan_County
# >>> reading 468.pax.zip.opex
# SEARCHING 51N_28W_-_Survey_Map_of_Powell_Township_Marquette_County
# >>> reading 2274.pax.zip.opex
# SEARCHING 07S_06W_-_Survey_Map_of_Ovid_Township_Branch_County
# >>> reading 221.pax.zip.opex
# SEARCHING 50N_32W_-_Survey_Map_of_LAnse_Township_Baraga_County
# >>> reading 2901.pax.zip.opex
# SEARCHING 07N_03W_-_Survey_Map_of_Bengal_Township_Clinton_County
# >>> reading 253.pax.zip.opex
# SEARCHING 20N_04W_-_Survey_Map_of_Frost_Township_Clare_County
# >>> reading 682.pax.zip.opex
# >>> reading 700.pax.zip.opex
# >>> reading 701.pax.zip.opex
# SEARCHING 06N_14W_-_Survey_Map_of_Blendon_Township_Ottawa_County
# >>> reading 459.pax.zip.opex
# SEARCHING 44N_07W_-_Survey_Map_of_Hendricks_Township_Mackinac_County
# >>> reading 805.pax.zip.opex
# SEARCHING 09N_01E_-_Survey_Map_of_Chapin_Township_Saginaw_County
# >>> reading 1601.pax.zip.opex
# SEARCHING 08S_18W_-_Survey_Map_of_Bertrand_Township_Berrien_County
# >>> reading 64.pax.zip.opex
# >>> reading 63.pax.zip.opex
# SEARCHING 41N_04E_-_Survey_Map_of_Detour_Township_Chippewa_County
# >>> reading 1975.pax.zip.opex
# >>> reading 1977.pax.zip.opex
# >>> reading 1976.pax.zip.opex
# SEARCHING 07N_04E_-_Survey_Map_of_Venice_Township_Shiawassee_County
# >>> reading 1557.pax.zip.opex
# SEARCHING 40N_31W_-_Survey_Map_of_Breitung_Township_and_Menominee_River_Is
# >>> reading 2714.pax.zip.opex
# >>> reading 2713.pax.zip.opex
# SEARCHING 48N_34W_-_Survey_Map_of_Covington_Township_Baraga_County
# >>> reading 2868.pax.zip.opex
# SEARCHING 40N_20W_-_Survey_Map_of_Ensign_Township_and_Nahma_Township_Delta
# >>> reading 2682.pax.zip.opex
# SEARCHING 11N_04W_-_Survey_Map_of_Sumner_Township_Gratiot_County
# >>> reading 721.pax.zip.opex
# SEARCHING 22N_05E_-_Survey_Map_of_Reno_Township_Iosco_County
# >>> reading 1326.pax.zip.opex
# SEARCHING 58N_27W_-_Survey_Map_of_Grant_Township_Keweenaw_County
# >>> reading 2380.pax.zip.opex
# SEARCHING 50N_27W_-_Survey_Map_of_Ishpeming_Township_and_Powell_Township_M
# >>> reading 2278.pax.zip.opex
# SEARCHING 38N_05W_-_Survey_Map_of_Bliss_Township_Emmet_County
# >>> reading 1081.pax.zip.opex
# SEARCHING 31N_06W_-_Survey_Map_of_Jordan_Township_Antrim_County
# >>> reading 2418.pax.zip.opex
# SEARCHING 26N_13W_-_Survey_Map_of_Inland_Township_Benzie_County
# >>> reading 967.pax.zip.opex
# SEARCHING 14N_13W_-_Survey_Map_of_Lincoln_Township_Newaygo_County
# >>> reading 555.pax.zip.opex
# SEARCHING 50N_42W_-_Survey_Map_of_Carp_Lake_Township_Ontonagon_County
# >>> reading 2543.pax.zip.opex
# SEARCHING 43N_11W_-_Survey_Map_of_Newton_Township_Mackinac_County
# >>> reading 2150.pax.zip.opex
# SEARCHING 13N_01E_-_Survey_Map_of_Mount_Haley_Township_Midland_County
# >>> reading 1354.pax.zip.opex
# SEARCHING 45N_42W_-_Survey_Map_of_Mareninsco_Township_Gogebic_County
# >>> reading 2465.pax.zip.opex
# SEARCHING 19N_11W_-_Survey_Map_of_Ellsworth_Township_Lake_County
# >>> reading 578.pax.zip.opex
# SEARCHING 31N_27W_-_Survey_Map_of_Menominee_Township_Menominee_County
# >>> reading 2756.pax.zip.opex
# SEARCHING 37N_19W_-_Survey_Map_of_Fairbanks_Township_and_Summer_Island_Del
# >>> reading 2706.pax.zip.opex
# SEARCHING 05N_05E_-_Survey_Map_of_Argentine_Township_Genesee_County
# >>> reading 1864.pax.zip.opex
# SEARCHING 07N_07W_-_Survey_Map_of_Easton_Township_Berlin_Township_Ionia_Co
# >>> reading 298.pax.zip.opex
# SEARCHING 07N_11W_-_Survey_Map_of_Grand_Rapids_Township_Kent_County
# >>> reading 382.pax.zip.opex
# >>> reading 383.pax.zip.opex
# SEARCHING 48N_08W_-_Survey_Map_of_McMillan_Township_Luce_County
# >>> reading 2123.pax.zip.opex
# SEARCHING 10N_12E_-_Survey_Map_of_Burnside_Township_Lapeer_County_and_Marl
# >>> reading 1845.pax.zip.opex
# SEARCHING 42N_32W_-_Survey_Map_of_Mastodon_Township_Iron_County
# >>> reading 2960.pax.zip.opex
# >>> reading 2961.pax.zip.opex
# SEARCHING 44N_28W_-_Survey_Map_of_Felch_Township_and_Westbranch_Township_D
# >>> reading 2999.pax.zip.opex
# SEARCHING 09N_17E_-_Survey_Map_of_Worth_Township_Sanilac_County
# >>> reading 1549.pax.zip.opex
# SEARCHING 20N_05E_-_Survey_Map_of_Mason_Township_Arenac_County
# >>> reading 1805.pax.zip.opex
# SEARCHING 45N_41W_-_Survey_Map_of_Watersmeet_Township_Gogebic_County
# >>> reading 2640.pax.zip.opex
# >>> reading 2641.pax.zip.opex
# SEARCHING 48N_09W_-_Survey_Map_of_Mc_Millan_Township_Luce_County
# >>> reading 2122.pax.zip.opex
# SEARCHING 46N_39W_-_Survey_Map_of_Haight_Township_Ontonagon_County
# >>> reading 2581.pax.zip.opex
# SEARCHING 13N_07W_-_Survey_Map_of_Millbrook_Township_Mecosta_County
# >>> reading 660.pax.zip.opex
# SEARCHING 15N_03E_-_Survey_Map_of_Beaver_Township_Bay_County
# >>> reading 1352.pax.zip.opex
# SEARCHING 06S_01E_-_Survey_Map_of_Rollin_Township_Lenawee_County
# >>> reading 1677.pax.zip.opex
# >>> reading 1676.pax.zip.opex
# SEARCHING 09N_01W_-_Survey_Map_of_Elba_Township_Gratiot_County
# >>> reading 262.pax.zip.opex
# >>> reading 261.pax.zip.opex
# SEARCHING 44N_01E_-_Survey_Map_of_Pickford_Township_Chippewa_County
# >>> reading 1917.pax.zip.opex
# >>> reading 1916.pax.zip.opex
# SEARCHING 03N_06W_-_Survey_Map_of_Vermontville_Township_Eaton_County
# >>> reading 341.pax.zip.opex
# SEARCHING 48N_10W_-_Survey_Map_of_McMillan_Township_Luce_County
# >>> reading 2119.pax.zip.opex
# SEARCHING 48N_21W_-_Survey_Map_of_Onota_Township_Alger_County
# >>> reading 2215.pax.zip.opex
# SEARCHING 04N_10E_-_Survey_Map_of_Orion_Township_Oakland_County
# >>> reading 1833.pax.zip.opex
# SEARCHING 04S_12W_-_Survey_Map_of_Prairie_Ronde_Township_Kalamazoo_County
# >>> reading 76.pax.zip.opex
# SEARCHING 10N_16E_-_Survey_Map_of_Lexington_Township_Sanilac_County
# >>> reading 1547.pax.zip.opex
# SEARCHING 01N_03E_-_Survey_Map_of_Unadilla_Township_Livingston_County
# >>> reading 1596.pax.zip.opex
# SEARCHING 55N_33W_-_Survey_Map_of_Osceola_Township_Torch_Lake_Township_and
# >>> reading 2504.pax.zip.opex
# SEARCHING 28N_09E_-_Survey_Map_of_Alcona_Township_Alcona_County
# >>> reading 1166.pax.zip.opex
# >>> reading 1167.pax.zip.opex
# >>> reading 1165.pax.zip.opex
# SEARCHING 47N_02E_-_Survey_Map_of_Sugar_Island_Chippewa_County
# >>> reading 1902.pax.zip.opex
# >>> reading 1903.pax.zip.opex
# SEARCHING 43N_07E_-_Survey_Map_of_Drummond_Island_Chippewa_County
# >>> reading 1942.pax.zip.opex
# >>> reading 1943.pax.zip.opex
# SEARCHING 20N_07E_-_Survey_Map_of_Whitney_Township_Arenac_County
# >>> reading 1824.pax.zip.opex
# SEARCHING 42N_35W_-_Survey_Map_of_Stambaugh_Township_Iron_County
# >>> reading 2668.pax.zip.opex
# >>> reading 2669.pax.zip.opex
# SEARCHING 37N_28W_-_Survey_Map_of_Faithorn_Township_and_Holmes_Township_Me
# >>> reading 2758.pax.zip.opex
# SEARCHING 24N_02W_-_Survey_Map_of_Higgins_Township_Roscommon_County
# >>> reading 776.pax.zip.opex
# SEARCHING 41N_05E_-_Survey_Map_of_Drummond_Island_Chippewa_County
# >>> reading 1973.pax.zip.opex
# >>> reading 1972.pax.zip.opex
# >>> reading 1971.pax.zip.opex
# SEARCHING 27N_09W_-_Survey_Map_of_the_Southern_half_of_Whitewater_Township
# >>> reading 897.pax.zip.opex
# >>> reading 896.pax.zip.opex
# SEARCHING 08S_05E_-_Survey_Map_of_Riga_Township_Lenawee_County
# >>> reading 1795.pax.zip.opex
# SEARCHING 11N_15E_-_Survey_Map_of_Washington_Township_Sanilac_County
# >>> reading 1526.pax.zip.opex
# SEARCHING 12N_06W_-_Survey_Map_of_Home_Township_Montcalm_County
# >>> reading 663.pax.zip.opex
# SEARCHING 18N_11W_-_Survey_Map_of_Pinora_Township_Lake_County
# >>> reading 582.pax.zip.opex
# SEARCHING 07S_04W_-_Survey_Map_of_Reading_Township_Hillsdale_County
# >>> reading 223.pax.zip.opex
# SEARCHING 51N_29W_-_Survey_Map_of_Michigamme_Township_and_Powell_Township_
# >>> reading 2273.pax.zip.opex
# SEARCHING 45N_18W_-_Survey_Map_of_Hiawatha_Township_Schoolcraft_County
# >>> reading 2198.pax.zip.opex
# SEARCHING 09N_14E_-_Survey_Map_of_Speaker_Township_Sanilac_County
# >>> reading 1552.pax.zip.opex
# SEARCHING 28N_03E_-_Survey_Map_of_Clinton_Township_Oscoda_County
# >>> reading 1172.pax.zip.opex
# SEARCHING 35N_29W_-_Survey_Map_of_Lake_Township_Menominee_County
# >>> reading 2739.pax.zip.opex
# SEARCHING 47N_28W_-_Survey_Map_of_Ely_Township_and_Tilden_Township_Marquet
# >>> reading 2287.pax.zip.opex
# SEARCHING 22N_06W_-_Survey_Map_of_Aetna_Township_Missaukee_County
# >>> reading 865.pax.zip.opex
# SEARCHING 19N_14E_-_Survey_Map_of_Austin_Township_Huron_County
# >>> reading 1816.pax.zip.opex
# SEARCHING 01S_11W_-_Survey_Map_of_Cooper_Township_Kalamazoo_County
# >>> reading 83.pax.zip.opex
# >>> reading 82.pax.zip.opex
# SEARCHING 28N_01W_-_Survey_Map_of_Lovells_Township_Crawford_County
# >>> reading 750.pax.zip.opex
# SEARCHING 42N_17W_-_Survey_Map_of_Inwood_Township_and_Thompson_Township_Sc
# >>> reading 2231.pax.zip.opex
# SEARCHING 05S_06E_-_Survey_Map_of_Milan_Township_Monroe_County
# >>> reading 1739.pax.zip.opex
# SEARCHING 29N_02W_-_Survey_Map_of_Chester_Township_Otsego_County
# >>> reading 745.pax.zip.opex
# SEARCHING 27N_14W_-_Survey_Map_of_Platte_Township_Benzie_County
# >>> reading 961.pax.zip.opex
# SEARCHING 07S_20W_-_Survey_Map_of_Chikaming_Township_Berrien_County
# >>> reading 28.pax.zip.opex
# SEARCHING 03S_16W_-_Survey_Map_of_Hartford_Township_Van_Buren_County
# >>> reading 10.pax.zip.opex
# SEARCHING 43N_19W_-_Survey_Map_of_Nahma_Township_Delta_County
# >>> reading 2227.pax.zip.opex
# SEARCHING 17N_09E_to_19N_09E_-_Survey_Map_of_islands_in_Saginaw_Bay
# >>> reading 1394.pax.zip.opex
# >>> reading 1393.pax.zip.opex
# >>> reading 1392.pax.zip.opex
# >>> reading 1395.pax.zip.opex
# >>> reading 1391.pax.zip.opex
# SEARCHING 48N_47W_-_Survey_Map_of_Ironwood_Township_Gogebic_County
# >>> reading 2520.pax.zip.opex
# SEARCHING 11N_11W_-_Survey_Map_of_Ensley_Township_Newaygo_County
# >>> reading 609.pax.zip.opex
# SEARCHING 37N_20W_-_Survey_Map_of_Island_in_Fairbanks_Township_Delta_Count
# >>> reading 2793.pax.zip.opex
# SEARCHING 14N_02E_-_Survey_Map_of_Midland_Township_Midland_County
# >>> reading 1280.pax.zip.opex
# >>> reading 1279.pax.zip.opex
# SEARCHING 42N_02E_-_Survey_Map_of_Raber_Township_Chippewa_County
# >>> reading 1891.pax.zip.opex
# SEARCHING 43N_34W_-_Survey_Map_of_Bates_Township_Iron_County
# >>> reading 2881.pax.zip.opex
# SEARCHING 51N_32W_-_Survey_Map_of_LAnse_and_Arvon_Townships_Baraga_County
# >>> reading 2271.pax.zip.opex
# SEARCHING 11N_13E_-_Survey_Map_of_Elmer_Township_Sanilac_County
# >>> reading 1524.pax.zip.opex
# SEARCHING 40N_23W_-_Survey_Map_of_Wells_Township_Delta_County
# >>> reading 2712.pax.zip.opex
# SEARCHING 07N_03E_-_Survey_Map_of_Caledonia_Township_Shiawassee_County
# >>> reading 1561.pax.zip.opex
# SEARCHING 28N_06E_-_Survey_Map_of_Caledonia_Township_Alcona_County
# >>> reading 1304.pax.zip.opex
# SEARCHING 48N_43W_-_Survey_Map_of_Bergland_Township_Ontonagon_County
# >>> reading 2521.pax.zip.opex
# SEARCHING 15N_04E_-_Survey_Map_of_Kawkawlin_Township_Bay_County
# >>> reading 1269.pax.zip.opex
# >>> reading 1270.pax.zip.opex
# SEARCHING 38N_02E_-_Survey_Map_of_Benton_Township_Cheboygan_County
# >>> reading 1107.pax.zip.opex
# SEARCHING 43N_03E_-_Survey_Map_of_Raber_Township_Chippewa_County
# >>> reading 1938.pax.zip.opex
# >>> reading 1939.pax.zip.opex
# >>> reading 1937.pax.zip.opex
# >>> reading 1940.pax.zip.opex
# SEARCHING 05S_10E_-_Survey_Map_of_Berlin_Township_Monroe_County_and_Browns
# >>> reading 1748.pax.zip.opex
# >>> reading 1749.pax.zip.opex
# >>> reading 1750.pax.zip.opex
# SEARCHING 25N_06W_-_Survey_Map_of_Garfield_Township_Kalkaska_County
# >>> reading 836.pax.zip.opex
# SEARCHING 28N_05W_-_Survey_Map_of_Blue_Lake_Township_Kalkaska_County
# >>> reading 842.pax.zip.opex
# SEARCHING 46N_27W_-_Survey_Map_of_Tilden_Township_Marquette_County
# >>> reading 2298.pax.zip.opex
# SEARCHING 47N_41W_-_Survey_Map_of_Marenisco_Township_Gogebic_County
# >>> reading 2580.pax.zip.opex
# SEARCHING 03S_07W_-_Survey_Map_of_Newton_Township_Calhoun_County
# >>> reading 172.pax.zip.opex
# SEARCHING 21N_10W_-_Survey_Map_of_Cherry_Grove_Township_Wexford_County
# >>> reading 958.pax.zip.opex
# SEARCHING 29N_15W_-_Survey_Map_of_the_Western_Portion_of_Glen_Arbor_Townsh
# >>> reading 974.pax.zip.opex
# SEARCHING 49N_13W_-_Survey_Map_of_Burt_Township_Alger_County
# >>> reading 2168.pax.zip.opex
# SEARCHING 29N_05E_-_Survey_Map_of_Ossineke_Township_Alpena_County
# >>> reading 1320.pax.zip.opex
# SEARCHING 06S_06E_-_Survey_Map_of_Summerfield_Township_and_Dundee_Township
# >>> reading 1735.pax.zip.opex
# SEARCHING 11N_16W_-_Survey_Map_of_Dalton_Township_Muskegon_County
# >>> reading 563.pax.zip.opex
# SEARCHING 35N_05W_-_Survey_Map_of_Little_Traverse_Township_and_Bear_Creek_
# >>> reading 1027.pax.zip.opex
# >>> reading 1026.pax.zip.opex
# >>> reading 1028.pax.zip.opex
# SEARCHING 50N_13W_-_Survey_Map_of_Burt_Township_Alger_County
# >>> reading 2152.pax.zip.opex
# SEARCHING 21N_04W_-Survey_Map_of_Roscommon_Township_Roscommon_County
# >>> reading 773.pax.zip.opex
# SEARCHING 13N_08W_-_Survey_Map_of_Hinton_Township_Mecosta_County
# >>> reading 659.pax.zip.opex
# SEARCHING 44N_10W_-_Survey_Map_of_Garfield_Township_Mackinac_County
# >>> reading 797.pax.zip.opex
# SEARCHING 41N_27W_-_Survey_Map_of_Breen_Township_Dickinson_County
# >>> reading 2265.pax.zip.opex
# SEARCHING 02N_06W_-Survey_Map_of_Kalamo_Township_Eaton_County
# >>> reading 345.pax.zip.opex
# SEARCHING 38N_04W_-_Survey_Map_of_Carp_Lake_Township_Emmet_County
# >>> reading 1098.pax.zip.opex
# SEARCHING 50N_38W_-_Survey_Map_of_Greenland_Township_Ontonagon_County
# >>> reading 2572.pax.zip.opex
# SEARCHING 26N_07E_-_Survey_Map_of_Millen_Township_Alcona_County
# >>> reading 1234.pax.zip.opex
# >>> reading 1233.pax.zip.opex
# SEARCHING 05S_01E_-_Survey_Map_of_Woodstock_Township_Lenawee_County
# >>> reading 1627.pax.zip.opex
# SEARCHING 28N_08W_-_Survey_Map_of_Clearwater_Township_Kalkaska_County
# >>> reading 852.pax.zip.opex
# SEARCHING 32N_05W_-_Survey_Map_of_Boyne_Valley_Township_Charlevoix_County
# >>> reading 1073.pax.zip.opex
# SEARCHING 34N_05E_-_Survey_Map_of_Belknap_Township_Presque_Isle_County
# >>> reading 1129.pax.zip.opex
# SEARCHING 47N_02W_-_Survey_Map_of_Bay_Mills_and_Superior_Townships_Chippew
# >>> reading 2018.pax.zip.opex
# >>> reading 2019.pax.zip.opex
# >>> reading 2017.pax.zip.opex
# >>> reading 2020.pax.zip.opex
# SEARCHING 49N_32W_-_Survey_Map_of_LAnse_Township_Baraga_County
# >>> reading 3014.pax.zip.opex
# SEARCHING 15N_08E_to_16N_08E_-_Survey_Map_of_islands_in_Saginaw_Bay_and_Ak
# >>> reading 1398.pax.zip.opex
# >>> reading 1397.pax.zip.opex
# SEARCHING 52N_32W_-_Survey_Map_of_LAnse_Township_Baraga_County
# >>> reading 2363.pax.zip.opex
# SEARCHING 17N_12E_-_Survey_Map_of_Meade_Township_Huron_County
# >>> reading 1504.pax.zip.opex
# SEARCHING 15N_15W_-_Survey_Map_of_Leavitt_Township_Oceana_County
# >>> reading 568.pax.zip.opex
# >>> reading 567.pax.zip.opex
# SEARCHING 08S_20W_-_Survey_Map_of_Three_Oaks_Township_Berrien_County
# >>> reading 32.pax.zip.opex
# SEARCHING 03S_03E_-_Survey_Map_of_Sharon_Township_Washtenaw_County
# >>> reading 1620.pax.zip.opex
# SEARCHING 12N_15E_-_Survey_Map_of_Bridgehampton_Township_Sanilac_County
# >>> reading 1518.pax.zip.opex
# SEARCHING 38N_10W_-_Survey_Map_of_Big_Beaver_Island_Peaine_Township_and_St
# >>> reading 2785.pax.zip.opex
# SEARCHING 02N_11W_-_Survey_Map_of_Martin_Township_Allegan_County
# >>> reading 407.pax.zip.opex
# SEARCHING 46N_23W_-_Survey_Map_of_Skania_Township_Marquette_County
# >>> reading 2266.pax.zip.opex
# SEARCHING 34N_28W_-_Survey_Map_of_Lake_Township_Menominee_County
# >>> reading 2747.pax.zip.opex
# SEARCHING 46N_17W_-_Survey_Map_of_Munising_Township_Alger_County
# >>> reading 2193.pax.zip.opex
# SEARCHING 01S_02E_-_Survey_Map_of_Waterloo_Township_Jackson_County
# >>> reading 1790.pax.zip.opex
# SEARCHING 12N_11W_-_Survey_Map_of_Croton_Township_Newaygo_County
# >>> reading 605.pax.zip.opex
# SEARCHING 44N_09W_-_Survey_Map_of_Garfield_Township_Mackinac_County
# >>> reading 2145.pax.zip.opex
# SEARCHING 41N_21W_-_Survey_Map_of_Ensign_Township_and_Masonville_Township_
# >>> reading 2108.pax.zip.opex
# >>> reading 2109.pax.zip.opex
# SEARCHING 08S_21W_-_Survey_Map_of_New_Buffalo_Township_Berrien_County
# >>> reading 33.pax.zip.opex
# SEARCHING 41N_14W_-_Survey_Map_of_Doyle_Township_Schoolcraft_County
# >>> reading 2189.pax.zip.opex
# SEARCHING 45N_45W_-_Survey_Map_of_Bessemer_Township_Gogebic_County
# >>> reading 2560.pax.zip.opex
# SEARCHING 65N_34W_-_Survey_Map_of_Houghton_Township_Isle_Royale_County
# >>> reading 2391.pax.zip.opex
# SEARCHING 07S_13W_-_Survey_Map_of_Porter_Township_Cass_County
# >>> reading 100.pax.zip.opex
# SEARCHING 19N_08W_-_Survey_Map_of_Hartwick_Township_Osceola_County
# >>> reading 642.pax.zip.opex
# SEARCHING 29N_10W_-_Survey_Map_of_Peninsula_Township_Grand_Traverse_County
# >>> reading 917.pax.zip.opex
# >>> reading 916.pax.zip.opex
# SEARCHING 23N_08E_-_Survey_Map_of_Wilber_Township_Iosco_County
# >>> reading 1324.pax.zip.opex
# SEARCHING 30N_05W_-_Survey_Map_of_Star_Township_Antrim_County
# >>> reading 829.pax.zip.opex
# SEARCHING 46N_31W_-_Survey_Map_of_Crystal_Falls_Township_Iron_County
# >>> reading 2906.pax.zip.opex
# SEARCHING 39N_22W_-_Survey_Map_of_Bay_de_Noc_Township_and_Wells_Township_D
# >>> reading 2690.pax.zip.opex
# SEARCHING 43N_25W_-_Survey_Map_Wells_and_Ewing_Townships_Marquette_County
# >>> reading 2222.pax.zip.opex
# SEARCHING 16N_05E_-_Survey_Map_of_Fraser_Township_Bay_County
# >>> reading 1812.pax.zip.opex
# SEARCHING 07N_08E_-_Survey_Map_of_Davison_Township_Genesee_County
# >>> reading 1855.pax.zip.opex
# SEARCHING 08S_19W_-_Survey_Map_of_Galien_Township_Berrien_County
# >>> reading 31.pax.zip.opex
# SEARCHING 34N_02W_-_Survey_Map_of_Ellis_Township_Cheboygan_County
# >>> reading 1066.pax.zip.opex
# SEARCHING 08N_15W_-_Survey_Map_of_Crockery_Township_Ottawa_County
# >>> reading 451.pax.zip.opex
# SEARCHING 47N_19W_-_Survey_Map_of_Au_Train_Township_Munising_Township_and_
# >>> reading 2241.pax.zip.opex
# SEARCHING 50N_44W_-_Survey_Map_of_Carp_Lake_Township_Ontonagon_County
# >>> reading 2534.pax.zip.opex
# SEARCHING 16N_10W_-_Survey_Map_of_Green_Township_Mecosta_County
# >>> reading 595.pax.zip.opex
# >>> reading 594.pax.zip.opex
# SEARCHING 31N_03E_-_Survey_Map_of_Hillman_Township_Montmorency_County
# >>> reading 1142.pax.zip.opex
# SEARCHING 14N_03W_-_Survey_Map_of_Chippewa_Township_Isabella_County
# >>> reading 712.pax.zip.opex
# SEARCHING 04S_08W_-_Survey_Map_of_Athens_Township_Calhoun_County
# >>> reading 181.pax.zip.opex
# SEARCHING 22N_02W_-_Survey_Map_of_Backus_Township_Roscommon_County
# >>> reading 784.pax.zip.opex
# SEARCHING 20N_12W_-_Survey_Map_of_Newkirk_Township_Lake_County
# >>> reading 573.pax.zip.opex
# SEARCHING 42N_32W_-_Survey_Map_of_Islands_in_Mastadon_Township_Iron_County
# >>> reading 2549.pax.zip.opex
# SEARCHING 49N_11W_-_Survey_Map_of_Mc_Millan_Township_Luce_County
# >>> reading 2121.pax.zip.opex
# SEARCHING 22N_09E_-_Survey_Map_of_Baldwin_Township_Iosco_County
# >>> reading 1823.pax.zip.opex
# SEARCHING 29N_12W_-_Survey_Map_of_Centerville_Township_Leelanau_County
# >>> reading 895.pax.zip.opex
# SEARCHING 27N_09E_-_Survey_Map_of_Haynes_Township_Alcona_County
# >>> reading 1802.pax.zip.opex
# SEARCHING 46N_25W_-_Survey_Map_of_Sands_Township_Marquette_County
# >>> reading 2296.pax.zip.opex
# SEARCHING 27N_04E_-_Survey_Map_of_Comins_Township_Oscoda_County
# >>> reading 1174.pax.zip.opex
# SEARCHING 02N_10E_-_Survey_Map_of_Bloomfield_Township_Oakland_County
# >>> reading 1839.pax.zip.opex
# SEARCHING 49N_31W_-_Survey_Map_of_Spurr_Township_Baraga_County
# >>> reading 2967.pax.zip.opex
# >>> reading 2966.pax.zip.opex
# SEARCHING 47N_16W_-_Survey_Map_of_Hiawatha_Township_Schoolcraft_County
# >>> reading 2083.pax.zip.opex
# >>> reading 2084.pax.zip.opex
# >>> reading 2082.pax.zip.opex
# >>> reading 2081.pax.zip.opex
# SEARCHING 38N_28W_-_Survey_Map_of_Faithorn_Township_Menominee_County
# >>> reading 2742.pax.zip.opex
# SEARCHING 02S_06W_-_Survey_Map_of_Marshall_Township_Calhoun_County
# >>> reading 144.pax.zip.opex
# SEARCHING 09N_04W_-_Survey_Map_of_North_Shade_Township_Gratiot_County
# >>> reading 245.pax.zip.opex
# SEARCHING 13N_06E_-_Survey_Map_of_Merritt_Township_Bay_County
# >>> reading 1480.pax.zip.opex
# SEARCHING 44N_24W_-_Survey_Map_of_Turin_Township_Marquette_County
# >>> reading 2213.pax.zip.opex
# SEARCHING 47N_46W_-_Survey_Map_of_Bessemer_Township_Gogebic_County
# >>> reading 2528.pax.zip.opex
# SEARCHING 20N_03E_-_Survey_Map_of_Moffatt_Township_Arenac_County
# >>> reading 1266.pax.zip.opex
# >>> reading 1267.pax.zip.opex
# SEARCHING 45N_25W_-_Survey_Map_of_Forsyth_Township_Marquette_County
# >>> reading 2260.pax.zip.opex
# >>> reading 2261.pax.zip.opex
# SEARCHING 51N_41W_-_Survey_Map_of_Carp_Lake_Township_and_Ontonagon_Townshi
# >>> reading 2498.pax.zip.opex
# SEARCHING 02N_14W_-_Survey_Map_of_Valley_Township_Allegan_County
# >>> reading 474.pax.zip.opex
# SEARCHING 02S_14W_-_Survey_Map_of_Waverly_Township_Van_Buren_County
# >>> reading 71.pax.zip.opex
# SEARCHING 48N_01E_-_Survey_Map_of_Sugar_Island_Chippewa_County
# >>> reading 1887.pax.zip.opex
# SEARCHING 42N_16W_-_Survey_Map_of_Thompson_Township_and_Hiawatha_Township_
# >>> reading 2230.pax.zip.opex
# SEARCHING 07S_03E_-_Survey_Map_of_Madison_Township_Lenawee_County
# >>> reading 1788.pax.zip.opex
# SEARCHING 16N_03W_-_Survey_Map_of_Wise_Township_Isabella_County
# >>> reading 707.pax.zip.opex
# >>> reading 706.pax.zip.opex
# SEARCHING 05N_03E_-_Survey_Map_of_Antrim_Township_Shiawassee_County
# >>> reading 1581.pax.zip.opex
# SEARCHING 41N_01W_-_Survey_Map_of_Clark_Township_and_Marquette_Island_Mack
# >>> reading 1995.pax.zip.opex
# >>> reading 1994.pax.zip.opex
# >>> reading 1993.pax.zip.opex
# SEARCHING 13N_18W_-_Survey_Map_of_Claybanks_Township_Oceana_County
# >>> reading 510.pax.zip.opex
# SEARCHING 45N_31W_-_Survey_Map_of_Mansfield_Township_Iron_County
# >>> reading 2995.pax.zip.opex
# SEARCHING 28N_11W_-_Survey_Map_of_Elmwood_Township_Leelanau_County
# >>> reading 889.pax.zip.opex
# SEARCHING 35N_27W_-_Survey_Map_of_Lake_Township_and_Stephenson_Township_Me
# >>> reading 2741.pax.zip.opex
# SEARCHING 19N_14W_-_Survey_Map_of_Sauble_Township_Lake_County
# >>> reading 539.pax.zip.opex
# SEARCHING 42-382
# >>> reading 2559.pax.zip.opex
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-f8719bb59e65> in <module>
#      13         with open(filepath) as fr:
#      14             contents = fr.read()
# ---> 15             collectMetadata(contents)
#
# <ipython-input-22-577c2565fdc5> in collectMetadata(data)
#      28     spatialCoverage = '{0}, {1}, Michigan|{1}, Michigan|Michigan'.format(township, county)
#      29
# ---> 30     TWNSHPLAB =  subdir.split('_')[0].strip('0') + ' ' + subdir.split('_')[1].strip('0')
#      31     try:
#      32         bbox = bboxDict[TWNSHPLAB]
#
# IndexError: list index out of range

# %%
with open('metadata.csv', 'w') as f:
    write = csv.writer(f)
      
    write.writerow(fieldnames)
    write.writerows(All_Metadata)
